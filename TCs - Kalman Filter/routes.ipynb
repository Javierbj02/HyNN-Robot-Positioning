# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, kstest, norm

# %%
data = pd.read_csv('C:/Users/javi2/Desktop/TFG - Webots/TFG/Test Case 1/Results/posiciones_ruta.csv')

# %%
plt.figure()
plt.scatter(data['RoundedX'], data['RoundedY'], s = 3, alpha = 1, c = 'blue')
plt.xlabel('x position [mm]')
plt.ylabel('y position [mm]')
# plt.grid(True)
# plt.axis('equal')
plt.xlim(-1400, -250) # Dist = 1150
plt.ylim(2850, 4000) # 2800 + 1150 

plt.show()

# %%
plt.figure()
plt.scatter(data['RoundedX'], data['RoundedY'], s = 3, alpha = 1, c = 'blue')
plt.xlabel('x position [mm]')
plt.ylabel('y position [mm]')
# plt.grid(True)
# plt.axis('equal')
# plt.xlim(-1400, -250) # Dist = 1150
# plt.ylim(2850, 4000) # 2800 + 1150 

plt.show()

# %%
data = pd.read_csv('C:/Users/javi2/Desktop/TFG - Webots/TFG/Test Case 2/Results/posiciones_ruta.csv')

# %%
plt.figure()
plt.scatter(data['RoundedX'], data['RoundedY'], s = 3, alpha = 1, c = 'blue')
plt.xlabel('x position [mm]')
plt.ylabel('y position [mm]')
# plt.grid(True)
# plt.axis('equal')
plt.xlim(-1400, -250) # Dist = 1150
plt.ylim(2850, 4000) # 2800 + 1150 

plt.show()

# %%
plt.figure()
plt.scatter(data['RoundedX'], data['RoundedY'], s = 3, alpha = 1, c = 'blue')
plt.xlabel('x position [mm]')
plt.ylabel('y position [mm]')
# plt.grid(True)
# plt.axis('equal')
# plt.xlim(-1400, -250) # Dist = 1150
# plt.ylim(2850, 4000) # 2800 + 1150 

plt.show()

# %%
data = pd.read_csv('C:/Users/javi2/Desktop/TFG - Webots/TFG/Test Case 3/Results/posiciones_ruta.csv')

# %%
plt.figure()
plt.scatter(data['RoundedX'], data['RoundedY'], s = 3, alpha = 1, c = 'blue')
plt.xlabel('x position [mm]')
plt.ylabel('y position [mm]')
# plt.grid(True)
# plt.axis('equal')
plt.xlim(-1400, -250) # Dist = 1150
plt.ylim(2850, 4000) # 2800 + 1150 

plt.show()

# %%
plt.figure()
plt.scatter(data['RoundedX'], data['RoundedY'], s = 3, alpha = 1, c = 'blue')
plt.xlabel('x position [mm]')
plt.ylabel('y position [mm]')
# plt.grid(True)
# plt.axis('equal')
# plt.xlim(-1400, -250) # Dist = 1150
# plt.ylim(2850, 4000) # 2800 + 1150 

plt.show()
